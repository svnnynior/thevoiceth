# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

from sklearn.manifold import TSNE

# %%
data = pd.read_excel('all_excel_fixed.xlsx')

# %%
df = data.drop(['contender', 'address', 'song'], axis=1)

# %%
sexuality_dict = {
    'M':0,
    'F':1,
    'D':2
}

genre_dict = {
    'Thai Country':0,
    'Pop':1,
    'Rock':2,
    'Alternative':3,
    'Country':4,
    'Jazz':5,
    'R&B':6,
    'Soul':5,
    'Acoustic':4,
    'Hip-Hop':3,
    'Blues':5
}

language_dict = {
    'th':0,
    'en':1,
    'jp':2,
    'kr':2,
    'cn':2
}

age_dict = {
    '<20':0,
    '21-29':1,
    '30-39':2,
    '>30':3,
}

# %%
def ageClassify(age):
    if age < 20: return '<20'
    elif age <= 40: return '20-40'
    else: return '>40'
    
df['sexuality'] = df['sexuality'].apply(lambda x: sexuality_dict[x])
df['genre'] = df['genre'].apply(lambda x: genre_dict[x])
df['language'] = df['language'].apply(lambda x: language_dict[x])
df['age'] = df['age'].apply(lambda x: ageClassify(x))

# %%
# df["num_coach"] = df.apply(lambda row: row[4] + row[5] + row[6] + row[7] + row[8] + row[9], axis = 1) # lambda function to check if they match. row.name gets the index

# %%
data_train = df[['sexuality', 'genre', 'language']]
np_data_train = data_train.values

# %%
np_data_train_normed = np_data_train / np_data_train.max(axis=0)

# %%
embedded = TSNE(n_components=2).fit_transform(np_data_train_normed)

# %%
x_tsne = embedded[:,0]
y_tsne = embedded[:,1]
embedded_df = pd.DataFrame({'x':x_tsne, 'y':y_tsne})

# %%
sns.regplot(x=x_tsne, y=y_tsne, fit_reg=False)
plt.show()

# %%
embedded_df = pd.DataFrame({'x':x_tsne, 'y':y_tsne})

# %%
concat_tsne_df = pd.concat([df,embedded_df],axis=1)

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=False, hue='num_coach_sel', legend=False)
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=True, hue='Joey', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=True, hue='Kim', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=True, hue='Stamp', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=True, hue='Kong', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=True, hue='Singto', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="x", y="y", data=concat_tsne_df, fit_reg=True, hue='Da', legend=False)
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
plt.show()

# %%
from kmodes.kmodes import KModes

# %%
km = KModes(n_clusters=6, init='Huang', n_init=100, verbose=1)

clusters = km.fit_predict(data_train)

# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 47, cost: 255.0
# Run 1, iteration: 2/100, moves: 0, cost: 255.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 257.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 53, cost: 270.0
# Run 3, iteration: 2/100, moves: 0, cost: 270.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 149, cost: 233.0
# Run 4, iteration: 2/100, moves: 6, cost: 233.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 16, cost: 317.0
# Run 5, iteration: 2/100, moves: 0, cost: 317.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 0, cost: 274.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 72, cost: 210.0
# Run 7, iteration: 2/100, moves: 5, cost: 210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves:
0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 73, iteration: 1/100, moves: 25, cost: 210.0
# Run 73, iteration: 2/100, moves: 0, cost: 210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 74, iteration: 1/100, moves: 88, cost: 257.0
# Run 74, iteration: 2/100, moves: 7, cost: 257.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 75, iteration: 1/100, moves: 7, cost: 252.0
# Run 75, iteration: 2/100, moves: 0, cost: 252.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 76, iteration: 1/100, moves: 0, cost: 284.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 77, iteration: 1/100, moves: 18, cost: 254.0
# Run 77, iteration: 2/100, moves: 0, cost: 254.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 78, iteration: 1/100, moves: 22, cost: 284.0
# Run 78, iteration: 2/100, moves: 0, cost: 284.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 79, iteration: 1/100, moves: 14, cost: 233.0
# Run 79, iteration: 2/100, moves: 0, cost: 233.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 80, iteration: 1/100, moves: 48, cost: 207.0
# Run 80, iteration: 2/100, moves: 0, cost: 207.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 81, iteration: 1/100, moves: 0, cost: 267.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 82, iteration: 1/100, moves: 0, cost: 256.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 83, iteration: 1/100, moves: 28, cost: 263.0
# Run 83, iteration: 2/100, moves: 0, cost: 263.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 84, iteration: 1/100, moves: 0, cost: 290.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 85, iteration: 1/100, moves: 9, cost: 261.0
# Run 85, iteration: 2/100, moves: 0, cost: 261.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 86, iteration: 1/100, moves: 27, cost: 199.0
# Run 86, iteration: 2/100, moves: 0, cost: 199.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 87, iteration: 1/100, moves: 35, cost: 220.0
# Run 87, iteration: 2/100, moves: 0, cost: 220.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 88, iteration: 1/100, moves: 6, cost: 266.0
# Run 88, iteration: 2/100, moves: 0, cost: 266.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 89, iteration: 1/100, moves: 72, cost: 242.0
# Run 89, iteration: 2/100, moves: 5, cost: 242.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 90, iteration: 1/100, moves: 36, cost: 247.0
# Run 90, iteration: 2/100, moves: 0, cost: 247.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 91, iteration: 1/100, moves: 0, cost: 226.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 92, iteration: 1/100, moves: 119, cost: 195.0
# Run 92, iteration: 2/100, moves: 13, cost: 195.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 93, iteration: 1/100, moves: 32, cost: 243.0
# Run 93, iteration: 2/100, moves: 0, cost: 243.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 94, iteration: 1/100, moves: 15, cost: 235.0
# Run 94, iteration: 2/100, moves: 0, cost: 235.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 95, iteration: 1/100, moves: 54, cost: 268.0
# Run 95, iteration: 2/100, moves: 0, cost: 268.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 96, iteration: 1/100, moves: 0, cost: 256.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 97, iteration: 1/100, moves: 63, cost: 205.0
# Run 97, iteration: 2/100, moves: 0, cost: 205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 98, iteration: 1/100, moves: 51, cost: 258.0
# Run 98, iteration: 2/100, moves: 0, cost: 258.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 99, iteration: 1/100, moves: 3, cost: 274.0
# Run 99, iteration: 2/100, moves: 0, cost: 274.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 100, iteration: 1/100, moves: 29, cost: 247.0
# Run 100, iteration: 2/100, moves: 0, cost: 247.0
# Best run was number 92
# [[1 1 0]
#  [1 0 0]
#  [0 1 1]
#  [0 2 0]
#  [0 1 0]
#  [1 1 1]]

# %%
cluster_df = pd.DataFrame({'cluster': clusters})

# %%
concat_df = pd.concat([df,cluster_df],axis=1)

# %%
# sns.stripplot(x="cluster", y="Joey", hue='sexuality', data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="sexuality", y="Joey", data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="genre", y="num_coach_sel", data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="genre", y="Joey", data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="genre", y="Stamp", data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="genre", y="Stamp", data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="genre", y="Kim", data=concat_df, jitter=True);
# plt.show()

# %%
# sns.stripplot(x="genre", y="Singto", data=concat_df, jitter=True);
# plt.show()

# %% [markdown]
# ## Coach Stats:  Percentage of Sexuality corresponding to Hitting Rate (WRONG ?)

# %%
Kong_df = df.loc[df['Kong'] == 1]
Kim_df = df.loc[df['Kim'] == 1]
Joey_df = df.loc[df['Joey'] == 1]
Stamp_df = df.loc[df['Stamp'] == 1]
Singto_df = df.loc[df['Singto'] == 1]
Da_df = df.loc[df['Da'] == 1]

dataframe_set = {
    'Kong':Kong_df,
    'Kim':Kim_df,
    'Joey':Joey_df,
    'Stamp':Stamp_df,
    'Singto':Singto_df,
    'Da':Da_df
}

coach_list = [
    'Kong',
    'Kim',
    'Joey',
    'Stamp',
    'Singto',
    'Da',
]

# %%
# sns.set_style("whitegrid")
# print('Percentage of Team Members Correspinding to Sexuality \n')
# for coach in coach_list:
#     sexuality_count = (dataframe_set[coach].groupby(['Kong'])['sexuality']
#                          .value_counts(normalize=True)
#                          .rename('percentage')
#                          .mul(100)
#                          .reset_index()
#                          .sort_values('sexuality'))
#     print(coach)
#     sns.barplot(x="sexuality", y="percentage", data=sexuality_count)
#     plt.show()

# %% [markdown]
# ## Coach Stats: Pick Rate Corresponding to Sexuality

# %%
for coach in coach_list:
    print(coach)
    percentage_count = (df.loc[df[coach] != -1].groupby(['sexuality'])[coach]
                             .value_counts(normalize=True)
                             .rename('percentage')
                             .mul(100)
                             .reset_index()
                             .sort_values(coach))
    sns.barplot(x=coach, y="percentage", hue="sexuality", data=percentage_count.loc[percentage_count[coach] == 1])
    plt.show()
# Out:
# Kong
# Kim
# Joey
# Stamp
# Singto
# Da

# %% [markdown]
# ## Coach Stats: Pick Rate Corresponding to Genre

# %%
for coach in coach_list:
    print(coach)
    percentage_count = (df.loc[df[coach] != -1].groupby(['genre'])[coach]
                             .value_counts(normalize=True)
                             .rename('percentage')
                             .mul(100)
                             .reset_index()
                             .sort_values(coach))
    sns.barplot(x=coach, y="percentage", hue="genre", data=percentage_count.loc[percentage_count[coach] == 1])
    plt.show()
# Out:
# Kong
# Kim
# Joey
# Stamp
# Singto
# Da

# %%
df['genre'].value_counts()
# Out:
# 1    171
# 0     54
# 4     48
# 2     40
# 5     29
# 6     26
# 3     20
# Name: genre, dtype: int64

# %% [markdown]
# ## Coach Stats: Pick Rate Corresponding to Age

# %%
for coach in coach_list:
    print(coach)
    percentage_count = (df.loc[df[coach] != -1].groupby(['age'])[coach]
                             .value_counts(normalize=True)
                             .rename('percentage')
                             .mul(100)
                             .reset_index()
                             .sort_values(coach))
    sns.barplot(x=coach, y="percentage", hue="age", data=percentage_count.loc[percentage_count[coach] == 1])
    plt.show()
# Out:
# Kong
# Kim
# Joey
# Stamp
# Singto
# Da

# %% [markdown]
# ## General Stats: Avg. Num Coach Sel per Genre
