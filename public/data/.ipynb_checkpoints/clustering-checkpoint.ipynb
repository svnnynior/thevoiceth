# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('all_excel.xlsx')

# %%
df = df.drop(['contender', 'address', 'song'], axis=1)

# %%
sexuality_dict = {
    'M':0,
    'F':1,
    'D':2
}

genre_dict = {
    'Thai Country':0,
    'Pop':1,
    'Rock':2,
    'Alternative':3,
    'Country':4,
    'Jazz':5,
    'R&B':6,
    'Soul':7,
    'Acoustic':8,
    'Hip-Hop':9,
    'Blues':10
}

language_dict = {
    'th':0,
    'en':1,
    'jp':2,
    'kr':3,
    'cn':4
}

age_dict = {
    '<20':0,
    '21-29':1,
    '30-39':2,
    '>30':3,
}

# %%
df['sexuality'] = df['sexuality'].apply(lambda x: sexuality_dict[x])
df['genre'] = df['genre'].apply(lambda x: genre_dict[x])
df['language'] = df['language'].apply(lambda x: language_dict[x])

# %%
data_train = df[['sexuality', 'genre', 'language']]
np_data_train = data_train.values

# %%
from sklearn.manifold import TSNE

# %%
np_data_train_normed = np_data_train / np_data_train.max(axis=0)

# %%
X_embedded = TSNE(n_components=2).fit_transform(data_train.values)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
x_tsne = X_embedded[:, 0]
y_tsne = X_embedded[:, 1]

# %%
sns.regplot(x=x_tsne, y=y_tsne, fit_reg=False)
plt.show()

# %%
from kmodes.kmodes import KModes

# %%
km = KModes(n_clusters=6, init='Huang', n_init=100, verbose=1)

clusters = km.fit_predict(data_train)

# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 17, cost: 193.0
# Run 2, iteration: 2/100, moves: 0, cost: 193.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 13, cost: 257.0
# Run 3, iteration: 2/100, moves: 0, cost: 257.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 37, cost: 209.0
# Run 4, iteration: 2/100, moves: 0, cost: 209.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 35, cost: 251.0
# Run 5, iteration: 2/100, moves: 0, cost: 251.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 2, cost: 258.0
# Run 6, iteration: 2/100, moves: 0, cost: 258.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 19, cost: 264.0
# Run 7, iteration: 2/100, moves: 0, cost: 264.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 2, cost: 250.0
# Run 8, iteration: 2/100, moves: 0, cost: 250.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 0, cost: 245.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 0, cost: 258.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 11, iteration: 1/100, moves: 0, cost: 273.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 12, iteration: 1/100, moves: 0, cost: 234.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 13, iteration: 1/100, moves: 0, cost: 225.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 14, iteration: 1/100, moves: 10, cost: 202.0
# Run 14, iteration: 2/100, moves: 0, cost: 202.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 15, iteration: 1/100, moves: 0, cost: 256.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 16, iteration: 1/100, moves: 0, cost: 223.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 17, iteration: 1/100, moves: 0, cost: 207.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 18, iteration: 1/100, moves: 16, cost: 200.0
# Run 18, iteration: 2/100, moves: 0, cost: 200.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 19, iteration: 1/100, moves: 51, cost: 200.0
# Run 19, iteration: 2/100, moves: 0, cost: 200.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 20, iteration: 1/100, moves: 115, cost: 236.0
# Run 20, iteration: 2/100, moves: 0, cost: 236.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 21, iteration: 1/100, moves: 0, cost: 282.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 22, iteration: 1/100, moves: 0, cost: 227.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 23, iteration: 1/100, moves: 33, cost: 248.0
# Run 23, iteration: 2/100, moves: 0, cost: 248.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 24, iteration: 1/100, moves: 28, cost: 257.0
# Run 24, iteration: 2/100, moves: 0, cost: 257.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 25, iteration: 1/100, moves: 0, cost: 253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 26, iteration: 1/100, moves: 130, cost: 200.0
# Run 26, iteration: 2/100, moves: 21, cost: 200.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 27, iteration: 1/100, moves: 82, cost: 252.0
# Run 27, iteration: 2/100, moves: 0, cost: 252.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 28, iteration: 1/100, moves: 0, cost: 234.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 29, iteration: 1/100, moves: 0, cost: 235.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 30, iteration: 1/100, moves: 79, cost: 186.0
# Run 30, iteration: 2/100, moves: 6, cost: 186.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 31, iteration: 1/100, moves: 0, cost: 215.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 32, iteration: 1/100, moves: 1, cost: 237.0
# Run 32, iteration: 2/100, moves: 0, cost: 237.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 33, iteration: 1/100, moves: 45, cost: 220.0
# Run 33, iteration: 2/100, moves: 0, cost: 220.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 34, iteration: 1/100, moves: 80, cost: 229.0
# Run 34, iteration: 2/100, moves: 0, cost: 229.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 35, iteration: 1/100, moves: 10, cost: 207.0
# Run 35, iteration: 2/100, moves: 0, cost: 207.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 36, iteration: 1/100, moves: 0, cost: 253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 37, iteration: 1/100, moves: 35, cost: 195.0
# Run 37, iteration: 2/100, moves: 0, cost: 195.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 38, iteration: 1/100, moves: 130, cost: 245.0
# Run 38, iteration: 2/100, moves: 0, cost: 245.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 39, iteration: 1/100, moves: 93, cost: 253.0
# Run 39, iteration: 2/100, moves: 17, cost: 253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 40, iteration: 1/100, moves: 68, cost: 210.0
# Run 40, iteration: 2/100, moves: 29, cost: 210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 41, iteration: 1/100, moves: 36, cost: 205.0
# Run 41, iteration: 2/100, moves: 0, cost: 205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 42, iteration: 1/100, moves: 32, cost: 210.0
# Run 42, iteration: 2/100, moves: 0, cost: 210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 43, iteration: 1/100, moves: 88, cost: 224.0
# Run 43, iteration: 2/100, moves: 16, cost: 224.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 44, iteration: 1/100, moves: 0, cost: 276.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 45, iteration: 1/100, moves: 65, cost: 243.0
# Run 45, iteration: 2/100, moves: 13, cost: 239.0
# Run 45, iteration: 3/100, moves: 1, cost: 239.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 46, iteration: 1/100, moves: 0, cost: 234.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 47, iteration: 1/100, moves: 0, cost: 218.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 48, iteration: 1/100, moves: 95, cost: 201.0
# Run 48, iteration: 2/100, moves: 48, cost: 201.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run
0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 81, iteration: 1/100, moves: 101, cost: 202.0
# Run 81, iteration: 2/100, moves: 0, cost: 202.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 82, iteration: 1/100, moves: 0, cost: 226.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 83, iteration: 1/100, moves: 53, cost: 193.0
# Run 83, iteration: 2/100, moves: 0, cost: 193.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 84, iteration: 1/100, moves: 89, cost: 217.0
# Run 84, iteration: 2/100, moves: 34, cost: 217.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 85, iteration: 1/100, moves: 0, cost: 216.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 86, iteration: 1/100, moves: 32, cost: 246.0
# Run 86, iteration: 2/100, moves: 0, cost: 246.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 87, iteration: 1/100, moves: 26, cost: 204.0
# Run 87, iteration: 2/100, moves: 0, cost: 204.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 88, iteration: 1/100, moves: 0, cost: 228.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 89, iteration: 1/100, moves: 0, cost: 243.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 90, iteration: 1/100, moves: 0, cost: 241.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 91, iteration: 1/100, moves: 0, cost: 275.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 92, iteration: 1/100, moves: 100, cost: 217.0
# Run 92, iteration: 2/100, moves: 6, cost: 217.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 93, iteration: 1/100, moves: 0, cost: 282.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 94, iteration: 1/100, moves: 0, cost: 239.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 95, iteration: 1/100, moves: 0, cost: 246.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 96, iteration: 1/100, moves: 53, cost: 250.0
# Run 96, iteration: 2/100, moves: 0, cost: 250.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 97, iteration: 1/100, moves: 0, cost: 244.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 98, iteration: 1/100, moves: 0, cost: 234.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 99, iteration: 1/100, moves: 0, cost: 251.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 100, iteration: 1/100, moves: 0, cost: 247.0
# Best run was number 30
# [[1 1 1]
#  [1 1 0]
#  [1 0 0]
#  [0 1 1]
#  [0 1 0]
#  [0 0 0]]

# %%
clusters.shape
# Out:
# (373,)

# %%
cluster_df = pd.DataFrame({'cluster': clusters})

# %%
concat_df = pd.concat([df,cluster_df],axis=1)

# %%
concat_df
# Out:
#      sexuality      age  genre  language  Kong  Kim  Joey  Stamp  Singto  Da  \
# 0            0       20      1         0     0    0     1      1       0   0
# 1            1       27      8         0     1    1     0      1       0   0
# 2            0       23      1         1     0    0     0      0       0   0
# 3            1       31      8         1     1    1     1      1       0   0
# 4            0       16      1         0     0    1     1      1       0   0
# 5            1       21      6         0     1    1     0      1       0   0
# 6            2    28,34      8         0     0    1     1      1       0   0
# 7            0       24      1         0     1    1     1      1       0   0
# 8            0       34      2         1     0    0     0      0       0   0
# 9            1       42      5         1     0    0     0      0       0   0
# 10           1       23      8         0     1    1     1      1       0   0
# 11           0       37      0         0     1    0     0      1       0   0
# 12           1       29      0         0     1    1     1      0       0   0
# 13           1       18      1         0     1    1     1      1       0   0
# 14           1       28      1         0     0    1     0      1       0   0
# 15           1       19      1         3     0    0     0      0       0   0
# 16           0       33      5         1     1    1     0      0       0   0
# 17           0       18      0         0     0    0     0      0       0   0
# 18           0       21      7         1     0    0     0      0       0   0
# 19           0       39      2         0     1    1     1      0       0   0
# 20           1       24      1         0     1    1     1      1       0   0
# 21           0       31      8         1     0    0     0      0       0   0
# 22           1       47      8         1     1    1     0      1       0   0
# 23           0       22      5         0     1    1     0      0       0   0
# 24           1       20      7         1     1    1     0      1       0   0
# 25           0       30      8         0     1    1     1      1       0   0
# 26           1       24      6         1     0    1     1      1       0   0
# 27           1       19      4         4     0    1     0      0       0   0
# 28           0       23      5         1     1    1     1      0       0   0
# 29           1       27      1         1     1    0     1      1       0   0
# ..         ...      ...    ...       ...   ...  ...   ...    ...     ...  ..
# 343          1       25      0         0     1    0     1      0       0   0
# 344          0       16      6         0     0    0     1      0       1   1
# 345          1       41      1         0     1    0     1      0       1   0
# 346          1       24      1         0     1    0     1      0       1   1
# 347          2  20 & 26      1         1     0    0     1      0       1   0
# 348          0       32      1         0     1    0     0      0       1   1
# 349          1       34      3         2     0    0     1      0       0   1
# 350          1       32      6         0     0    0     0      0       0   0
# 351          0       19      1         0     1    0     1      0       1   0
# 352          1       16      1         0     1    0     1      0       1   1
# 353          1       28      2         1     1    0     0      0       0   1
# 354          1       23      2         1     1    0     1      0       1   0
# 355          1       28      0         0     0    0     0      0       0   0
# 356          0       27      1         0     0    0     1      0       1   1
# 357          0       43      0         0     1    0     0      0       1   1
# 358          1       18      1         2     1    0     1      0       1   0
# 359          1       22      1         0     0    0     1      0       1   1
# 360          1       22      1         0     1    0     1      0       1   1
# 361          1       19      9         0     0    0     0      0       0   0
# 362          1       30      0         0     0    0     1      0       1   1
# 363          1       25      3         1     1    0     1      0       1   0
# 364          1       17      6         0     1    0     1      0       1   0
# 365          1       18      0         0     1    0     0      0       1   1
# 366          0       20      1         0     1    0     1      0       1   1
# 367          1       16      0         0     1    0     1      0       0   1
# 368          1       29      0         0     1    0     1      0       1   0
# 369          1       23      2         1     1    0     1      0       0   1
# 370          0       27      0         0     1    0     1      0       1   1
# 371          0       60      2         1     0    0     1      0       0   1
# 372          0       33      1         0     1    0     0      0       1   1
#
#      cluster
# 0          4
# 1          1
# 2          3
# 3          0
# 4          4
# 5          1
# 6          1
# 7          4
# 8          3
# 9          0
# 10         1
# 11         5
# 12         2
# 13         1
# 14         1
# 15         0
# 16         3
# 17         5
# 18         3
# 19         4
# 20         1
# 21         3
# 22         0
# 23         4
# 24         0
# 25         4
# 26         0
# 27         0
# 28         3
# 29         0
# ..       ...
# 343        2
# 344        4
# 345        1
# 346        1
# 347        0
# 348        4
# 349        0
# 350        1
# 351        4
# 352        1
# 353        0
# 354        0
# 355        2
# 356        4
# 357        5
# 358        0
# 359        1
# 360        1
# 361        1
# 362        2
# 363        0
# 364        1
# 365        2
# 366        4
# 367        2
# 368        2
# 369        0
# 370        5
# 371        3
# 372        4
#
# [373 rows x 11 columns]
